# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("./R04_50")

# %%
dataset.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
dataset.head()
# Out:
#    Fc5.  Fc3.  Fc1.  Fcz.  Fc2.  Fc4.  Fc6.  C5..  C3..  C1..  ...  Po7.  \
# 0  -5.0   2.0  37.0  39.0  30.0  26.0 -16.0 -14.0   4.0  18.0  ...  -8.0
# 1 -12.0 -24.0   1.0  -2.0 -15.0 -22.0 -55.0 -36.0 -27.0 -25.0  ... -40.0
# 2 -77.0 -78.0 -59.0 -65.0 -63.0 -55.0 -67.0 -88.0 -71.0 -65.0  ... -22.0
# 3 -66.0 -67.0 -50.0 -65.0 -60.0 -55.0 -68.0 -62.0 -53.0 -54.0  ... -60.0
# 4 -45.0 -55.0 -33.0 -53.0 -54.0 -63.0 -83.0 -52.0 -50.0 -53.0  ... -55.0
#
#    Po3.  Poz.  Po4.  Po8.  O1..  Oz..  O2..  Iz..  label
# 0 -35.0 -45.0 -66.0 -39.0 -33.0 -48.0 -39.0 -39.0      0
# 1 -68.0 -65.0 -84.0 -52.0 -21.0 -42.0 -31.0 -34.0      0
# 2 -50.0 -35.0 -48.0 -18.0 -20.0 -42.0 -29.0 -27.0      0
# 3 -78.0 -64.0 -68.0 -41.0 -44.0 -62.0 -34.0 -43.0      0
# 4 -70.0 -54.0 -63.0 -37.0 -60.0 -70.0 -34.0 -45.0      0
#
# [5 rows x 65 columns]

# %%
dataset.shape
# Out:
# (986000, 65)

# %%
from sklearn.model_selection import train_test_split
X = dataset.drop(columns={"label"})
Y = dataset['label']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
X_train = np.array(X_train)
X_test = np.array(X_test)
scaler = StandardScaler()
X_train_scaled =  scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_reshaped = X_train_scaled.reshape(X_train.shape[0],X_train.shape[1],1)
X_test_reshaped = X_test_scaled.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
train_accuracies = []

# %%
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128,kernel_size=3,activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 100
for epoch in range(epochs):
    print(f"epoch {epoch+1}/100")
    history = model.fit(X_train_reshaped, Y_train, epochs=1)  
    train_accuracies.append(history.history['acc'][0])
# Out:
# epoch 1/100
# Train on 788800 samples
# 788800/788800 [==============================] - 86s 109us/sample - loss: 0.9410 - acc: 0.5509
# epoch 2/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.8197 - acc: 0.6204
# epoch 3/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.7593 - acc: 0.6520
# epoch 4/100
# Train on 788800 samples
# 788800/788800 [==============================] - 82s 104us/sample - loss: 0.7244 - acc: 0.6694
# epoch 5/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.7006 - acc: 0.6814
# epoch 6/100
# Train on 788800 samples
# 788800/788800 [==============================] - 84s 106us/sample - loss: 0.6830 - acc: 0.6904
# epoch 7/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6691 - acc: 0.6968
# epoch 8/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6576 - acc: 0.7019
# epoch 9/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6490 - acc: 0.7065
# epoch 10/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6416 - acc: 0.7101
# epoch 11/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6356 - acc: 0.7131
# epoch 12/100
# Train on 788800 samples
# 788800/788800 [==============================] - 84s 106us/sample - loss: 0.6292 - acc: 0.7163
# epoch 13/100
# Train on 788800 samples
# 788800/788800 [==============================] - 82s 104us/sample - loss: 0.6252 - acc: 0.7179
# epoch 14/100
# Train on 788800 samples
# 788800/788800 [==============================] - 82s 104us/sample - loss: 0.6207 - acc: 0.7200
# epoch 15/100
# Train on 788800 samples
# 788800/788800 [==============================] - 84s 106us/sample - loss: 0.6169 - acc: 0.7218
# epoch 16/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6146 - acc: 0.7231
# epoch 17/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6113 - acc: 0.7245
# epoch 18/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 106us/sample - loss: 0.6100 - acc: 0.7254
# epoch 19/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6074 - acc: 0.7264
# epoch 20/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6060 - acc: 0.7278
# epoch 21/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.
100
# Train on 788800 samples
# 788800/788800 [==============================] - 82s 104us/sample - loss: 0.6193 - acc: 0.7240
# epoch 83/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6208 - acc: 0.7239
# epoch 84/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 106us/sample - loss: 0.6249 - acc: 0.7223
# epoch 85/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 106us/sample - loss: 0.6262 - acc: 0.7216
# epoch 86/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6257 - acc: 0.7213
# epoch 87/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6239 - acc: 0.7226
# epoch 88/100
# Train on 788800 samples
# 788800/788800 [==============================] - 84s 107us/sample - loss: 0.6271 - acc: 0.7210
# epoch 89/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6275 - acc: 0.7215
# epoch 90/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 106us/sample - loss: 0.6317 - acc: 0.7209
# epoch 91/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6345 - acc: 0.7196
# epoch 92/100
# Train on 788800 samples
# 788800/788800 [==============================] - 82s 105us/sample - loss: 0.6355 - acc: 0.7200
# epoch 93/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6356 - acc: 0.7192
# epoch 94/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6341 - acc: 0.7206
# epoch 95/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6323 - acc: 0.7203
# epoch 96/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6335 - acc: 0.7203
# epoch 97/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6409 - acc: 0.7169
# epoch 98/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6470 - acc: 0.7150
# epoch 99/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6452 - acc: 0.7160
# epoch 100/100
# Train on 788800 samples
# 788800/788800 [==============================] - 83s 105us/sample - loss: 0.6427 - acc: 0.7161

# %%
test_loss, test_accuracy = model.evaluate(X_test_reshaped, Y_test, verbose=0)

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Loss: 0.6798
# Test Accuracy: 0.6975

# %%
print(train_accuracies)
# Out:
# [0.55089754, 0.62038285, 0.65201825, 0.6693902, 0.6813793, 0.6903689, 0.6968446, 0.70192444, 0.70645666, 0.71010774, 0.71305275, 0.71629435, 0.7178714, 0.71996707, 0.7218281, 0.7231263, 0.7244967, 0.7253689, 0.7264224, 0.7277814, 0.7281947, 0.72939277, 0.7301851, 0.72998476, 0.73100024, 0.7320981, 0.7327206, 0.7333025, 0.7332974, 0.73384, 0.73383874, 0.73405045, 0.7342191, 0.73463744, 0.7345246, 0.73516864, 0.7349163, 0.7353752, 0.73511666, 0.7348935, 0.73483264, 0.73530173, 0.73519015, 0.73523706, 0.73460954, 0.73432046, 0.7343281, 0.7352573, 0.7346894, 0.7346767, 0.7348441, 0.7334242, 0.73377407, 0.7341785, 0.73419625, 0.73322517, 0.7336486, 0.73271805, 0.733589, 0.73281187, 0.7316354, 0.73176724, 0.7311866, 0.7303879, 0.73068964, 0.7297452, 0.72968054, 0.73013943, 0.72936356, 0.7287779, 0.7291468, 0.72942066, 0.7262145, 0.72783595, 0.72790694, 0.7266937, 0.7259648, 0.7237411, 0.7254323, 0.7252104, 0.72215897, 0.72397184, 0.72387046, 0.7222642, 0.72160244, 0.72132224, 0.7226204, 0.7210104, 0.7215302, 0.7209457, 0.71958923, 0.7199518, 0.7191975, 0.720554, 0.7202789, 0.7202903, 0.7169232, 0.7149987, 0.71596605, 0.71607]

# %%
epochs_list = [i for i in range(1,epochs+1)]
plt.figure(figsize=(40,10))
plt.plot(epochs_list, train_accuracies, marker='o', linestyle='-')
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy vs. Epochs')
plt.grid(True)
plt.xticks(range(1, 101))

plt.show()
